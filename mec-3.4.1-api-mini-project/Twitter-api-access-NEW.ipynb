# %% [markdown]
# # this file holds how to access twitter, reddit and yahoo finance code for datasets
# #
# # Twitter access code - get tweets for a single stock

# %%
import tweepy as twitter
import os
import dotenv

import pandas as pd

from dotenv import load_dotenv

# %%
# get the API access keys from file .env

load_dotenv()  # take environment variables from .env.
config = dotenv.dotenv_values(".env")   # config = {"USER": "foo", "EMAIL": "foo@example.org"}

print(config)

# keys and tokens from the Twitter Dev Console
consumer_key = config.get('consumer_key')
consumer_secret = config.get('consumer_secret')
access_token = config.get('access_token')
access_token_secret = config.get('access_token_secret')
# Out:
# OrderedDict([('consumer_key', '0r3gTc4w2OCnUcimnZsejmzXm'), ('consumer_secret', 'cjOHhBoQH5rGFfhDmpt5oS8FegYXuVOKjlCBm5ZRJyWn2AktSg'), ('access_token', '29489350-HqS8DnyFO0ccw37DxQ9HsyXKvJgC2rbxYqmthGCDG'), ('access_token_secret', 'EOYSNpR7gSIzdVHO4NgPGAQeObT1rllxh05E4gNik2uXg')])

# %% [markdown]
# setup access info for Twitter

# %% [markdown]
# authenticate

# %%
auth = twitter.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
auth.access_token = access_token
API = twitter.API(auth)


# function to perform data extraction
def getTweets(words, date_since, numtweet):

        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])

        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = twitter.Cursor(API.search_tweets,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)


        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]

        # Counter to maintain Tweet Count
        i = 1

        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                createdAt = tweet.entities[]
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']

                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])

                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet

                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'tweet_details.csv'

        # we will save our database as a CSV file.
        db.to_csv(filename)

# %%
def main():
    # test a query with twitter
    public_tweets = API.home_timeline()
    # print(public_tweets)

    aapl_tweets = API.search_tweets(q = '$AAPL')
    #aapl_tweets = API.search_30_day(q = '$AAPL')
    #print(aapl_tweets)


    # Enter Hashtag and initial date
    # Enter Twitter Stock to search for
    words = "$TSLA"
    # Enter Date since The Tweets are required in yyyy-mm--dd"
    date_since = "2022-03-01"

    # number of tweets you want to extract in one run
    numtweet = 100
    getTweets(words, date_since, numtweet)


    # SaveData
    # what is current directory?
    cwd = os.getcwd()
    print("Current directory = " + cwd)
    # save it to a file in data_sets directory
    file2 = open(r"./datasets/twitter_api_search_query_results.txt","w+")
    # write all tweets to the file
    for tweet in aapl_tweets:
        file2.write("{}\n".format(tweet))
        #print(tweet['created_at'], tweet['id'], tweet['user']['id'], tweet['user']['name'], tweet['user']['followers_count'], tweet['text'])
    # close the file handle
    file2.close()
    
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")
        

if __name__ == "__main__":
    # calling main function
    main()
# Out:
# Tweet 1:
# Username:henryfaroh09
# Description:
# Location:Barquisimeto , Venezuela
# Following Count:4828
# Follower Count:1254
# Total Tweets:232001
# Retweet Count:32
# Tweet Text:Different investment types have different goals
#
# You can have a MIXED plan as well and be VERY successful
#
# Dividends
# $KO
# $MO
# $HD
# $V
# $SBUX
#
# Blue Chip
# $AAPL
# #MSFT
# $GOOGL
# $AMZN
#
# Growth
# $TSLA
# $NVDA
# $CRWD
# $SQ
# $SHOP
#
# REITs
# $O
# $STOR
# $PSA
# $STAG
#
# Which is your GO TO type? https://t.co/u3BBdzltPe
# Hashtags Used:[]
#
# Tweet 2:
# Username:abhisheknb91
# Description:🇺🇸 If you really want to do something, you'll find a way. If you don't, you'll find an excuse. 🇺🇸
# Location:Fort Drum, NY 🇺🇸
# Following Count:99
# Follower Count:48
# Total Tweets:3273
# Retweet Count:0
# Tweet Text:$TSLA do they’ll provide more information about the split on earnings? ️
# Hashtags Used:[]
#
# Tweet 3:
# Username:Alejuarez117
# Description:International Relations degree🏴‍☠️🌎       Look around🕶⚡️
# Location:
# Following Count:751
# Follower Count:79
# Total Tweets:238
# Retweet Count:4
# Tweet Text:The ELITES don’t want Elon Musk to own $TWTR.
#
# @DavidSacks explains 😤
#
# #TwitterTakeover #ElonMuskBuyTwitter  $TSLA https://t.co/GdpBqPlGSd
# Hashtags Used:['TwitterTakeover', 'ElonMuskBuyTwitter']
#
# Tweet 4:
# Username:AnitaPeck11
# Description:Healthcare. Antifash. Resister. Get vaccinated. Love my family.
# Location:Paradise
# Following Count:646
# Follower Count:711
# Total Tweets:211183
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 5:
# Username:iamoyegun
# Description:Author | Fiction and nonfiction. Entrepreneur | Bunker Trading.
# Location:Here and There
# Following Count:5000
# Follower Count:2653
# Total Tweets:1138
# Retweet Count:4
# Tweet Text:The ELITES don’t want Elon Musk to own $TWTR.
#
# @DavidSacks explains 😤
#
# #TwitterTakeover #ElonMuskBuyTwitter  $TSLA https://t.co/GdpBqPlGSd
# Hashtags Used:['TwitterTakeover', 'ElonMuskBuyTwitter']
#
# Tweet 6:
# Username:wordjuggler
# Description:Brain dragging around a body. Bernie ForFuckingEver! Catholic Atheist, military brat, INTJ, Democratic Socialist. Art and Science, $TSLAQ
# Location:Boise, Idaho
# Following Count:2046
# Follower Count:947
# Total Tweets:54328
# Retweet Count:1
# Tweet Text:🔹Do 🇪🇺 buyers prefer to wait for a MY "made in Germany"?
#
# People who ordered MY in 2020, expecting delivery from Germany, got delivered in 2021 out of China.
#
# Not sure you can specify manufacture / origin via $TSLA salespeople either.
# Hashtags Used:[]
#
# Tweet 7:
# Username:cgruttke
# Description:
# Location:Arizona
# Following Count:509
# Follower Count:143
# Total Tweets:4451
# Retweet Count:15
# Tweet Text:Tesla of the day. The kids loved this one. The supercharger network is one of teslas best assets… $tsla #tesla https://t.co/IMlNxyabJi
# Hashtags Used:['tesla']
#
# Tweet 8:
# Username:wildrosetreasur
# Description:My hobby is crocheting and knitting for my children, grandchildren and great grandchildren.
# Location:
# Following Count:450
# Follower Count:242
# Total Tweets:20476
# Retweet Count:300
# Tweet Text:BREAKING: Elon Musk’s speaking to investors who could partner with to buy Twitter - NYP
#
# One possibility sources said: teaming with PE firm Silver Lake Partners, which was planning to co-invest with him in 2018 when he was considering taking $TSLA private.
# https://t.co/jGC2I4NzFs
# Hashtags Used:[]
#
# Tweet 9:
# Username:shitadelnft
# Description:I like to brainstorm trading ideas here
# Location:San Francisco, CA
# Following Count:56
# Follower Count:65
# Total Tweets:1384
# Retweet Count:4
# Tweet Text:After about 2 months being active on $twtr my conclusion is discovery is not that great. Feels like I am in $tsla $pltr + tech liberal echo chamber. I love you all guys, but would be interesting to hear a bit about other things from time to time - bring randomness into the mix
# Hashtags Used:[]
#
# Tweet 10:
# Username:wordjuggler
# Description:Brain dragging around a body. Bernie ForFuckingEver! Catholic Atheist, military brat, INTJ, Democratic Socialist. Art and Science, $TSLAQ
# Location:Boise, Idaho
# Following Count:2046
# Follower Count:947
# Total Tweets:54328
# Retweet Count:1
# Tweet Text:Who has any good explanation for these low-mileage "used" 2022 MY in Denmark?
#
# 🔹Are these test-drive cars that were first registered to $TSLA DK? Probably not, as usually test-drive cars are listed as "demo" under *NEW*
#
# 🔹Is $TSLA shifting 🇪🇺 inventory between EU countries?
# Hashtags Used:[]
#
# Tweet 11:
# Username:ohmahahm
# Description:테슬라 주주 커뮤니티 운영자
# (참여링크 : https://t.co/ssB7rGEvex)
# Location:Capitalism
# Following Count:3835
# Follower Count:17462
# Total Tweets:128891
# Retweet Count:7
# Tweet Text:$TSLA $AMD and $TWTR are the most mentioned tickers on WSB today
# Hashtags Used:[]
#
# Tweet 12:
# Username:Stock_Farms
# Description:Always Searching For Stocks That Can Grow ~
# Location:
# Following Count:111
# Follower Count:825
# Total Tweets:7026
# Retweet Count:0
# Tweet Text:@elonmusk @business Elon @elonmusk - Why NOT keep $TWTR Public Trading on the NYSE 🤔
# $TSLA ♾
# Hashtags Used:[]
#
# Tweet 13:
# Username:ElectroCar
# Description:
# Location:Arizona, USA
# Following Count:924
# Follower Count:1160
# Total Tweets:86214
# Retweet Count:54
# Tweet Text:From my Chinese friend:
#
# Tesla is on the list of businesses that "must be restored."
#
# Same with its suppliers.
#
# $TSLA https://t.co/dznH0P3U7v
# Hashtags Used:[]
#
# Tweet 14:
# Username:wordjuggler
# Description:Brain dragging around a body. Bernie ForFuckingEver! Catholic Atheist, military brat, INTJ, Democratic Socialist. Art and Science, $TSLAQ
# Location:Boise, Idaho
# Following Count:2046
# Follower Count:947
# Total Tweets:54328
# Retweet Count:1
# Tweet Text:This is perhaps small-time speculation from a dealer really believing that $TSLA has a 7 months-long order backlog, and trying to exploit that via impatient eager buyers, concert-ticket-scalper-style.
#
# There are 2022 MY in almost *any* 🇪🇺 country on any used car platform. https://t.co/eQGoiJKCDB
# Hashtags Used:[]
#
# Tweet 15:
# Username:Tumble_W33D
# Description:It is the mark of an educated mind to be able to entertain a thought without accepting it.
# Location:WWW upside-down world
# Following Count:1760
# Follower Count:1177
# Total Tweets:134720
# Retweet Count:300
# Tweet Text:BREAKING: Elon Musk’s speaking to investors who could partner with to buy Twitter - NYP
#
# One possibility sources said: teaming with PE firm Silver Lake Partners, which was planning to co-invest with him in 2018 when he was considering taking $TSLA private.
# https://t.co/jGC2I4NzFs
# Hashtags Used:[]
#
# Tweet 16:
# Username:VickiBryanBondA
# Description:Founder & CEO, Bond Angle, LLC 25 yrs high yield investment mgmt & research. Ok if Smart $ doesn't agree. We'll see. https://t.co/BM3lNAW70j
# Location:USA
# Following Count:2807
# Follower Count:3878
# Total Tweets:7777
# Retweet Count:0
# Tweet Text:On deck: Recall #2 after $TSLA OTA “fix” failed to correct previous recall re boombox feature impairs proximity alert for pedestrians. Same for failed heat pumps finally recalled &amp; not fixed after several OTA attempts &amp; finally needed full service repairs. https://t.co/xWYteWZLba
# Hashtags Used:[]
#
# Tweet 17:
# Username:KitsTech_
# Description:Software Engineer(Splunk), Tesla enthusiast, Model Y owner, Review, road-trips and family lifestyle.
# Location:Washington, DC
# Following Count:463
# Follower Count:289
# Total Tweets:3206
# Retweet Count:0
# Tweet Text:I kinda regret not getting the performance Model Y instead. Is the acceleration boost worth it? Or should I just go ahead and order a performance Model Y? $tsla #tesla
# Hashtags Used:['tesla']
#
# Tweet 18:
# Username:LittleRaven_1
# Description:Simultaneously evolving and dissolving.
# Location:The Trouble You Know
# Following Count:258
# Follower Count:16
# Total Tweets:3822
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 19:
# Username:wordjuggler
# Description:Brain dragging around a body. Bernie ForFuckingEver! Catholic Atheist, military brat, INTJ, Democratic Socialist. Art and Science, $TSLAQ
# Location:Boise, Idaho
# Following Count:2046
# Follower Count:947
# Total Tweets:54328
# Retweet Count:16
# Tweet Text:$TSLA European delivery cycle Q2 2022:
#
# It is best to think of Elon's offer for $TWTR, and the Shanghai COVID lockdown, as one big distraction from the observable facts:
#
# 🚨 $TSLA still not sold out of Q1 inventory! 🚨
# Hashtags Used:[]
#
# Tweet 20:
# Username:Maddy56406762
# Description:
# Location:
# Following Count:5007
# Follower Count:1062
# Total Tweets:22475
# Retweet Count:9
# Tweet Text:More information on $TSLA split should come out in the coming 2-3 weeks.
# Hashtags Used:[]
#
# Tweet 21:
# Username:EricFlut
# Description:new here? check the pinned tweet and some of the hashtags to see my history:
# #WytPeoplesCourt #GQPSnowflakes #WhiteFear #raciststack **********not always polite
# Location:
# Following Count:4923
# Follower Count:3109
# Total Tweets:34640
# Retweet Count:11
# Tweet Text:🚨 In the long-running lawsuit against Musk and Tesla for the "funding secured" saga, the Defendants have taken a huge blow to their case before trial next month. They will not be able to argue to the jury that Musk's tweets were accurate or not misleading. $tsla $tslaq https://t.co/wBRmybt54t
# Hashtags Used:[]
#
# Tweet 22:
# Username:Susie39212967
# Description:Government & Politics Health General News Sports Politics Comedy, Married to my sweetie heart. Please don't DM me.
# Location:El Cajon, CA
# Following Count:2699
# Follower Count:2271
# Total Tweets:230676
# Retweet Count:11
# Tweet Text:🚨 In the long-running lawsuit against Musk and Tesla for the "funding secured" saga, the Defendants have taken a huge blow to their case before trial next month. They will not be able to argue to the jury that Musk's tweets were accurate or not misleading. $tsla $tslaq https://t.co/wBRmybt54t
# Hashtags Used:[]
#
# Tweet 23:
# Username:antonsterenborg
# Description:Tesla | Engineer | Vegan | Baritone | Running | DFI | looking in wonder to the universe and everything in it
# Location:Mars
# Following Count:1339
# Follower Count:571
# Total Tweets:16017
# Retweet Count:0
# Tweet Text:@stevenmarkryan No conviction in $TWTR
# 100% conviction in $TSLA
# Hashtags Used:[]
#
# Tweet 24:
# Username:passthebeano
# Description:Yes, I did have a burrito for lunch. Why do you ask?
# Location:
# Following Count:1408
# Follower Count:2728
# Total Tweets:53299
# Retweet Count:0
# Tweet Text:@ClaireMusk I'm not following the exact numbers,  but doesn't Musk's $2B+ $TWTR buy wipe out his newfound $TSLA cash?
#
# $TSLAQ
# Hashtags Used:[]
#
# Tweet 25:
# Username:MirageWL8
# Description:mind over matter :) ⛰🌊🌎🧠 the world is as beautiful as you make it!
# Location:Vancouver, British Columbia
# Following Count:643
# Follower Count:180
# Total Tweets:2177
# Retweet Count:0
# Tweet Text:@elonmusk is the only person I have a notification on Twitter for. Idgaf about anybody else $TSLA
# Hashtags Used:[]
#
# Tweet 26:
# Username:Susie39212967
# Description:Government & Politics Health General News Sports Politics Comedy, Married to my sweetie heart. Please don't DM me.
# Location:El Cajon, CA
# Following Count:2699
# Follower Count:2271
# Total Tweets:230676
# Retweet Count:4
# Tweet Text:...order was to give the parties time to request specific redactions and Musk jumped the gun, which it appears he did, then why should those requests be granted? $TSLA
# Hashtags Used:[]
#
# Tweet 27:
# Username:Susie39212967
# Description:Government & Politics Health General News Sports Politics Comedy, Married to my sweetie heart. Please don't DM me.
# Location:El Cajon, CA
# Following Count:2699
# Follower Count:2271
# Total Tweets:230676
# Retweet Count:6
# Tweet Text:Even if Musk succeeded in convincing Judge Chen that he has not met the standard for technical civil contempt of court, Chen would be well within his rights to simply ignore all of Musk's and $TSLA's redaction requests. If the reason for sealing the... https://t.co/pzXITbFjok
# Hashtags Used:[]
#
# Tweet 28:
# Username:_tyler_durdn_
# Description:Computer Science and Software Enthusiast | Indian | Currently in states
# Location:
# Following Count:193
# Follower Count:16
# Total Tweets:7749
# Retweet Count:41
# Tweet Text:For those who can’t get through Barron’s paywall.  $tsla $twtr https://t.co/VFQKaQaBzN
# Hashtags Used:[]
#
# Tweet 29:
# Username:Susie39212967
# Description:Government & Politics Health General News Sports Politics Comedy, Married to my sweetie heart. Please don't DM me.
# Location:El Cajon, CA
# Following Count:2699
# Follower Count:2271
# Total Tweets:230676
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 30:
# Username:ninjanikki000
# Description:Imma ninja
# Location:
# Following Count:512
# Follower Count:66
# Total Tweets:6217
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 31:
# Username:Ynjames6396
# Description:Malaysian Chinese (retired).
# 马来西亚华裔【退休】。
# Location:Kuala Lumpur, Wilayah Persekut
# Following Count:1474
# Follower Count:2985
# Total Tweets:66006
# Retweet Count:7
# Tweet Text:Shanghai Municipal Commission of Economy and Informatization issues guidelines for resumption of work and production, urging all district governments, streets, and towns to actively support enterprises to resume work and production.
# #China #Shanghai $TSLA
# https://t.co/RoLBIELAKU
# Hashtags Used:[]
#
# Tweet 32:
# Username:JonBryant421
# Description:Opinion, analysis of interesting topics; not investment advice. CFA, former buyside, sellside securities professsional. Startup survivor.
# Location:
# Following Count:2380
# Follower Count:926
# Total Tweets:41893
# Retweet Count:1
# Tweet Text:While @tesla's directors are co-conspirators to all that has gone on at least they were smart enough to settle.
# $TSLA https://t.co/0nfjuqCgN2
# Hashtags Used:[]
#
# Tweet 33:
# Username:OppayahTwitR
# Description:Tesla Model 3 owner as of July 7, 2018 and soon to be Y owner. I’m here to learn and share my Tesla experience. Accumulating $TSLA on every dip since 2016.
# Location:United States
# Following Count:246
# Follower Count:1267
# Total Tweets:21356
# Retweet Count:0
# Tweet Text:@elonmusk I take this tweet as a good sign of something good happening to $TSLA. Thank you Elon!
# Hashtags Used:[]
#
# Tweet 34:
# Username:RennLee3
# Description:Carefully managing ❤ 🇷🇺
# Location:Trivandrum,  India
# Following Count:2719
# Follower Count:146
# Total Tweets:3513
# Retweet Count:99
# Tweet Text:I give you the hypocrisy of the main stream media. $twtr $tsla https://t.co/gTuixGplPD
# Hashtags Used:[]
#
# Tweet 35:
# Username:MatthewCGerard
# Description:Father. Husband. Entrepreneur. Tech Oriented, Data Driven Problem Solver. #HumanityFirst #AI
# Location:California, USA
# Following Count:1078
# Follower Count:2151
# Total Tweets:82776
# Retweet Count:2
# Tweet Text:This new twitter holdco stock would become the new twitter stock. Investors could take a combo or cash or stock in the new company. But Elon could then afford to raise the offer to $69 which would get the job done.  $twtr $tsla
# Hashtags Used:[]
#
# Tweet 36:
# Username:arny_trezzi
# Description:Bet against Mr. Market to make a living • 100% Tech • $PLTR obsessed.
# Location:Italy
# Following Count:143
# Follower Count:750
# Total Tweets:2657
# Retweet Count:0
# Tweet Text:@SawyerMerritt $TSLA ufficially the “new Apple” 😂
# Hashtags Used:[]
#
# Tweet 37:
# Username:Kansas_Cash
# Description:Stock Market Genius
# Location:Kansas USA
# Following Count:41
# Follower Count:74
# Total Tweets:4893
# Retweet Count:0
# Tweet Text:$SPY $TSLA $AAPL $ETH.X ”Stunning” “Brave” “A Masterpiece” KansasCash Spring 2022 NFT collection  https://t.co/FmiNhm1cpF
# Hashtags Used:[]
#
# Tweet 38:
# Username:huskies5876
# Description:Rose de Lima
# Location:
# Following Count:652
# Follower Count:232
# Total Tweets:18612
# Retweet Count:2
# Tweet Text:Twitter let’s your mind, words &amp; intellect make you sexy. 💕
#
# $TSLA #Tesla
# Hashtags Used:['Tesla']
#
# Tweet 39:
# Username:bnhunter3273
# Description:
# Location:Los Angeles, CA
# Following Count:175
# Follower Count:74
# Total Tweets:77405
# Retweet Count:73
# Tweet Text:BREAKING--Investment bankers crunching numbers on how @elonmusk can finance a takeover of @Twitter have come up with this scenario: Do a stock swap, exchanging $43B-plus of his $TSLA shares for $TWTR shares since the investor base is similar (growth) and its a non taxable event.
# Hashtags Used:[]
#
# Tweet 40:
# Username:AccentInvesting
# Description:I will teach you how to manage money and be financially literate. I share insights on finance and wealth. Level up with me. DMs are open.
# Location:Get my book and Subscribe 👇🏿
# Following Count:240
# Follower Count:13988
# Total Tweets:33694
# Retweet Count:32
# Tweet Text:Different investment types have different goals
#
# You can have a MIXED plan as well and be VERY successful
#
# Dividends
# $KO
# $MO
# $HD
# $V
# $SBUX
#
# Blue Chip
# $AAPL
# #MSFT
# $GOOGL
# $AMZN
#
# Growth
# $TSLA
# $NVDA
# $CRWD
# $SQ
# $SHOP
#
# REITs
# $O
# $STOR
# $PSA
# $STAG
#
# Which is your GO TO type? https://t.co/u3BBdzltPe
# Hashtags Used:[]
#
# Tweet 41:
# Username:jamessalcedo
# Description:Dad. Expert software developer. Mechanical/Aerospace Engineer.Swimmer.Texan. 🇿🇦🇲🇽 🇮🇳 🇵🇰 🇳🇬 🇰🇪 🇪🇸 🇨🇦 🇮🇪 🇨🇳🏴󠁧󠁢󠁳󠁣󠁴󠁿 🇺🇦 🇷🇺 🖤❤️ ♀️
# Location:I ❤️ u. 💕💕
# Following Count:2154
# Follower Count:2372
# Total Tweets:4106
# Retweet Count:300
# Tweet Text:BREAKING: Elon Musk’s speaking to investors who could partner with to buy Twitter - NYP
#
# One possibility sources said: teaming with PE firm Silver Lake Partners, which was planning to co-invest with him in 2018 when he was considering taking $TSLA private.
# https://t.co/jGC2I4NzFs
# Hashtags Used:[]
#
# Tweet 42:
# Username:ocshree
# Description:I write about Puppies, Porsches, and Peloton. World traveler. Grad of Harvey Mudd and UCLA Anderson. CIO at Pelican. 🐋 shot by me in Husavik.
# Location:California
# Following Count:645
# Follower Count:2897
# Total Tweets:4047
# Retweet Count:0
# Tweet Text:Some good reading from the SEC.
#
# Note: I am not an M&amp;A expert. Just an interested individual investor in $TSLA
#
# https://t.co/NYgj3FQUH6
# Hashtags Used:[]
#
# Tweet 43:
# Username:EdzAaron79
# Description:Working class Debt Slave and crypto  Enthusiast Believer in Elon Musk and #DogecoinToTheMoon
# Location:St Louis, MO
# Following Count:1074
# Follower Count:440
# Total Tweets:9126
# Retweet Count:0
# Tweet Text:Poll Find 73% Want Elon Musk To Takeover Twitter; The Tesla CEO Responds $TSLA $TWTR https://t.co/lKJu8oJve4 via @Benzinga
# Hashtags Used:[]
#
# Tweet 44:
# Username:VegasREinvestor
# Description:On Twitter looking for uplifting news, business news, fun stories and occasional political rant. Tweets are for fun only. See your Doctor if you disagree w/me.
# Location:Las Vegas, Duh it's in my name
# Following Count:751
# Follower Count:125
# Total Tweets:6257
# Retweet Count:0
# Tweet Text:@itslevie @COorBust @DavidSacks @WholeMarsBlog They could just say Elon's way to open source twitter is not for the good of the company. Done Fiduciary duty fulfilled.
# Bringing back the likes of Trumps isn't going to make twitter tons of money like $Tsla has, nor turning this into 4chan/gab/parler like "free speech" either.
# Hashtags Used:[]
#
# Tweet 45:
# Username:ravi_tejrai
# Description:A dead thing can go with the stream, but only a living thing can go against it. 🇺🇸
# Location:LOS ANGELES, CA
# Following Count:75
# Follower Count:39
# Total Tweets:2469
# Retweet Count:0
# Tweet Text:$TSLA sigh the car isn't coming with the charger anymore this is why companies like Apple suck they allow this 🚩 https://t.co/s6sgcmW1NN
# Hashtags Used:[]
#
# Tweet 46:
# Username:IrinaAntony
# Description:Love 💖Peace🕊Joy 🌸 - Present Moment 🌄 💫
# Location:Ireland, Cork
# Following Count:1013
# Follower Count:1952
# Total Tweets:106727
# Retweet Count:15
# Tweet Text:Tesla of the day. The kids loved this one. The supercharger network is one of teslas best assets… $tsla #tesla https://t.co/IMlNxyabJi
# Hashtags Used:['tesla']
#
# Tweet 47:
# Username:_fractalFinance
# Description:•fractalFinance BOT•   •data science and nature based algorithms• •powered by R• •FREE #MandelbrotChannels•
# Location:
# Following Count:102
# Follower Count:51
# Total Tweets:302
# Retweet Count:0
# Tweet Text:@justfootclothes
#
# $TSLA 1m #MandelbrotChannel
# |--975.056 &lt;= 985 =&gt; 1216.167--|
#
# |--BUY &lt;=currentPrice=&gt; SELL--|
# math &gt; opinion https://t.co/LrsCBx5wTV
# Hashtags Used:['MandelbrotChannel']
#
# Tweet 48:
# Username:007_mufc
# Description:
# Location:London, England
# Following Count:958
# Follower Count:69
# Total Tweets:5295
# Retweet Count:207
# Tweet Text:Cathie Wood’s @ARKInvest has set their 2026 price target for $TSLA at $4,600
# Hashtags Used:[]
#
# Tweet 49:
# Username:MatthewCGerard
# Description:Father. Husband. Entrepreneur. Tech Oriented, Data Driven Problem Solver. #HumanityFirst #AI
# Location:California, USA
# Following Count:1078
# Follower Count:2151
# Total Tweets:82776
# Retweet Count:5
# Tweet Text:Typically when companies have poison pills the way around it is to make an offer they can’t refuse.  That’s one that’s high enough the majority would tender their shares. #twitter #tesla $twtr $tsla
# Hashtags Used:[]
#
# Tweet 50:
# Username:Aliciatweetzz
# Description:
# Location:
# Following Count:399
# Follower Count:53
# Total Tweets:135
# Retweet Count:2
# Tweet Text:Twitter let’s your mind, words &amp; intellect make you sexy. 💕
#
# $TSLA #Tesla
# Hashtags Used:['Tesla']
#
# Tweet 51:
# Username:Jasperlope
# Description:Ex-Texan | +Sparks🐶 | Bay Area Game Dev | Cute Furry stuff + exasperated political stuff | 🔞 likes may be lewd 🔞
# Location:West Bay, Northern California
# Following Count:2126
# Follower Count:558
# Total Tweets:62539
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 52:
# Username:trade_tipper
# Description:Alerts on stocks and cryptos sentiments so you are on the right side of the market. This is not investment advice.
# Location:NYC
# Following Count:45
# Follower Count:4719
# Total Tweets:10654
# Retweet Count:0
# Tweet Text:Bear down $BE $GME $LICY $TSLA $WISH $FB 🐻. https://t.co/1p0nnKn9KF
# Hashtags Used:[]
#
# Tweet 53:
# Username:dissectmarkets
# Description:Contrarian Investor | Finance Blogger | Dividend Investing | Web 3.0 | Crypto
# Location:Blog 👉
# Following Count:355
# Follower Count:1869
# Total Tweets:50414
# Retweet Count:0
# Tweet Text:$TSLA will see rising demand for EVs as taxi cab companies and rideshare platforms start implanting zero-emission mandates.
#
# $UBER and $LYFT already have mandates by 2030. https://t.co/STgvVhy7RB
# Hashtags Used:[]
#
# Tweet 54:
# Username:robinivski
# Description:No matter what the stripper tells you * There's no sex in the Champagne Room * Owner of the world's first https://t.co/64ewL6DSyv short shorts
# Location:Belgium
# Following Count:995
# Follower Count:1707
# Total Tweets:34773
# Retweet Count:0
# Tweet Text:@passthebeano @elonmusk @jack Make sure that you don't get paid in $TSLA shares 😜
# Hashtags Used:[]
#
# Tweet 55:
# Username:emcverse
# Description:knowledge is power, $TSLA and #safemoon investor. Trade sometimes. Lets change for the better.
# Location:
# Following Count:466
# Follower Count:292
# Total Tweets:13424
# Retweet Count:2
# Tweet Text:This new twitter holdco stock would become the new twitter stock. Investors could take a combo or cash or stock in the new company. But Elon could then afford to raise the offer to $69 which would get the job done.  $twtr $tsla
# Hashtags Used:[]
#
# Tweet 56:
# Username:CachDang
# Description:🇺🇸 The mind is its own place, and in itself can make a heaven of hell, a hell of heaven.. 🇺🇸
# Location:Yelm, WA 🇺🇸
# Following Count:25
# Follower Count:46
# Total Tweets:2274
# Retweet Count:0
# Tweet Text:$TSLA BRQS....get in or miss big 👀 https://t.co/b6fGd4lcwY
# Hashtags Used:[]
#
# Tweet 57:
# Username:passthebeano
# Description:Yes, I did have a burrito for lunch. Why do you ask?
# Location:
# Following Count:1408
# Follower Count:2728
# Total Tweets:53299
# Retweet Count:0
# Tweet Text:@Grimezsz Seriously (kinda), who has the dimensions of a roll of nickles vs the batteries in various Teslas?
#
# $TSLA $TSLAQ @Grimezsz @elonmusk
# Hashtags Used:[]
#
# Tweet 58:
# Username:dollyllamaX10
# Description:Living in a wee castle in the woods surrounded by a moat and protected by polydactyls. She/her or whatever.
# *Warning: sometimes acerbic. (Acct. restart)
# Location:Back of Beyond and then some
# Following Count:1568
# Follower Count:546
# Total Tweets:38735
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 59:
# Username:MatthewCGerard
# Description:Father. Husband. Entrepreneur. Tech Oriented, Data Driven Problem Solver. #HumanityFirst #AI
# Location:California, USA
# Following Count:1078
# Follower Count:2151
# Total Tweets:82776
# Retweet Count:1
# Tweet Text:If Elon offers a number that gets over 51% tendered. Then twitter BOD of NON shareholders would be forced to take the bid as its their fiduciary duty. It’s easy to reject $54 all cash bid. But not a tender play at a much higher price. $twtr $tsla
# Hashtags Used:[]
#
# Tweet 60:
# Username:ThomasMihailos
# Description:
# Location:Brooklyn, NY
# Following Count:785
# Follower Count:187
# Total Tweets:35805
# Retweet Count:4
# Tweet Text:...order was to give the parties time to request specific redactions and Musk jumped the gun, which it appears he did, then why should those requests be granted? $TSLA
# Hashtags Used:[]
#
# Tweet 61:
# Username:ThomasMihailos
# Description:
# Location:Brooklyn, NY
# Following Count:785
# Follower Count:187
# Total Tweets:35805
# Retweet Count:6
# Tweet Text:Even if Musk succeeded in convincing Judge Chen that he has not met the standard for technical civil contempt of court, Chen would be well within his rights to simply ignore all of Musk's and $TSLA's redaction requests. If the reason for sealing the... https://t.co/pzXITbFjok
# Hashtags Used:[]
#
# Tweet 62:
# Username:srsundar33
# Description:Fairy tales are more than true: not because they tell us that dragons exist, but because they tell us that dragons can be beaten.
# Location:Clearwater, FL 🇺🇸🇺🇸🇺🇸
# Following Count:259
# Follower Count:44
# Total Tweets:3256
# Retweet Count:0
# Tweet Text:$TSLA earnings Wednesday, TSLA up or down? ⏩
# Hashtags Used:[]
#
# Tweet 63:
# Username:MemesOfMars
# Description:Tesla / SpaceX / Memes / Mars 👨‍💻 $TSLA https://t.co/KrwGeP9gvu
# Location:Germany
# Following Count:962
# Follower Count:3546
# Total Tweets:34321
# Retweet Count:0
# Tweet Text:The Science of a Poison Pill to fend of @elonmusk Twitter bid.
#
# $TSLA #TESLA @TESLA https://t.co/Bl5mbpCXlt
# Hashtags Used:['TESLA']
#
# Tweet 64:
# Username:David_Hansell
# Description:Belvidere Central Middle School Geography Bee Champion (2003)
# Location:
# Following Count:587
# Follower Count:20
# Total Tweets:2856
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 65:
# Username:BenjaminBaca7
# Description:Reading the word of God, dancing, trying new things, hanging our with friends.
# Location:
# Following Count:3690
# Follower Count:79
# Total Tweets:5193
# Retweet Count:64
# Tweet Text:$TSLA appears ready to restart production in Giga Shanghai on Monday with at least one shift, increasing to two shifts by end of April.  https://t.co/rKfNJ3Bu8k
# Hashtags Used:[]
#
# Tweet 66:
# Username:NickSpitaliere
# Description:I love my gf and stocks
# Location:
# Following Count:114
# Follower Count:38
# Total Tweets:188
# Retweet Count:41
# Tweet Text:For those who can’t get through Barron’s paywall.  $tsla $twtr https://t.co/VFQKaQaBzN
# Hashtags Used:[]
#
# Tweet 67:
# Username:ThomasMihailos
# Description:
# Location:Brooklyn, NY
# Following Count:785
# Follower Count:187
# Total Tweets:35805
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 68:
# Username:Teslaconomics
# Description:I keep it simple, truthful, and filter the noise: long-term $TSLA shareholder & #TESLA tweeter ⚡️🔋🚘🔋⚡️ *NOT A FINANCIAL ADVISOR*
# Location:Space
# Following Count:188
# Follower Count:28760
# Total Tweets:10118
# Retweet Count:2
# Tweet Text:Twitter let’s your mind, words &amp; intellect make you sexy. 💕
#
# $TSLA #Tesla
# Hashtags Used:['Tesla']
#
# Tweet 69:
# Username:cnzelibe
# Description:BCOP & MBA
# I work on probabilistic odds
# Location:
# Following Count:37
# Follower Count:130
# Total Tweets:1937
# Retweet Count:29
# Tweet Text:GOOD LORD...Earnings Season upon us
#
# This week notables: $NFLX $TSLA
# Following week: $MSFT $GOOG $AMZN $AAPL $TWTR $FB OH MY. PLACE YOUR BETS. https://t.co/inKwmbCLps
# Hashtags Used:[]
#
# Tweet 70:
# Username:MyStockNewsfeed
# Description:I Share Stock Market News 📈📉 | Not A Financial Advisor | Big on Tesla, EVs, & Tech | Model 3, Y, & Future Cybertruck Owner | $TSLA $AAPL $GOOG $NVDA $ETH #BTC
# Location:WeBull Referral Link
# Following Count:46
# Follower Count:1853
# Total Tweets:9849
# Retweet Count:0
# Tweet Text:Tesla now doesn't let anyone buy their car after lease is over as used car prices are skyrocketing
#
# $TSLA https://t.co/JyZBi4OnRl
# Hashtags Used:[]
#
# Tweet 71:
# Username:MyStockNewsfeed
# Description:I Share Stock Market News 📈📉 | Not A Financial Advisor | Big on Tesla, EVs, & Tech | Model 3, Y, & Future Cybertruck Owner | $TSLA $AAPL $GOOG $NVDA $ETH #BTC
# Location:WeBull Referral Link
# Following Count:46
# Follower Count:1853
# Total Tweets:9849
# Retweet Count:0
# Tweet Text:Tesla unveils giant new 360 MWh Megapack project that is going to help power 60,000 homes
#
# $TSLA https://t.co/fP5be3HRa6
# Hashtags Used:[]
#
# Tweet 72:
# Username:JoseLuc36212787
# Description:ELON MUSK'S FOLLOWER ALL THE WAY
# (NIKOLA TESLA)
# Space exploration follower
# Location:
# Following Count:539
# Follower Count:167
# Total Tweets:25999
# Retweet Count:99
# Tweet Text:I give you the hypocrisy of the main stream media. $twtr $tsla https://t.co/gTuixGplPD
# Hashtags Used:[]
#
# Tweet 73:
# Username:fintwit_tracker
# Description:Tracking trending stocks among the most influential traders on #fintwits
# Location:Miami, FL
# Following Count:651
# Follower Count:8359
# Total Tweets:25157
# Retweet Count:0
# Tweet Text:Trending Stocks on #fintwit:
#
# Source: https://t.co/cWJOwWSb0I
#
# 1. $SPX 🥇
# 2. $TWTR 🥈
# 3. $TSLA 🥉
# 4. $SPY
# 5. $QQQ
# 6. $BTC
# 7. $FB
# 8. $NVDA
# 9. $INMD
# 10. $SKLZ
#
# ( Sorted by most recent ) https://t.co/08TmDOBirN
# Hashtags Used:['fintwit']
#
# Tweet 74:
# Username:ShootYallPhotog
# Description:Photographer, woodworker, Navy brat/Army wife, love nature-animals-java, loathe bullies/fake patriots @cactusandivy
# Location:South Carolina
# Following Count:3448
# Follower Count:1014
# Total Tweets:22864
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 75:
# Username:RonMadison11
# Description:Ex-enterprise SaaS tech exec, now tech investor + biz owner. Accountant by trade 🤓. I follow and post about growth stocks like $TSLA and $OPEN + catch frauds.
# Location:Canada
# Following Count:2002
# Follower Count:1708
# Total Tweets:17510
# Retweet Count:5
# Tweet Text:Typically when companies have poison pills the way around it is to make an offer they can’t refuse.  That’s one that’s high enough the majority would tender their shares. #twitter #tesla $twtr $tsla
# Hashtags Used:[]
#
# Tweet 76:
# Username:topstonks
# Description:Wanna know where #stonks are in the hype cycle? We vacuum up data from the stock talk dungeons & present this wisdom to you on #topstonks
# Location:
# Following Count:1178
# Follower Count:3166
# Total Tweets:109212
# Retweet Count:0
# #tsla    #wallstreetbets  #investing https://t.co/MLdQQOjZ1Sned on wallstreetbets over the last 24 hours
# Hashtags Used:['tsla', 'wallstreetbets', 'investing']
#
# Tweet 77:
# Username:JohnJohnpetrou4
# Description:Let’s go
# Location:
# Following Count:45
# Follower Count:37
# Total Tweets:5963
# Retweet Count:15
# Tweet Text:The new ARK bear case for $TSLA is $2,900 in 2026.  The Stephenson Indicator™️ is $2,958.  Further evidence that this linear / dumb* projection could be a great conservative estimate of future gains!
#
# * With all due respect to @ICannot_Enough 😄 https://t.co/kQR8cAwyQw
# Hashtags Used:[]
#
# Tweet 78:
# Username:jgcOCANADA
# Description:🤩Dual citizen 🇺🇸🇨🇦 PennStateAlum
# Why did my PA01 Congressman Brian Fitzpatrick take 💰💰💰from convict Elliott Broidy? He's also BFF with Fruman/Parnas!🤔
# Location:
# Following Count:4547
# Follower Count:2801
# Total Tweets:163083
# Retweet Count:10
# Tweet Text:@BradMunchen @NHTSAgov @NTSB @HimoraSlimane Tesla Recalls Model X Over Front Side Airbags That Don't Inflate
#
# The recall affects model years 2021 and 2022 and encompasses a little over 7,000 vehicles.
#
# $TSLA $TSLAQ
#
# https://t.co/LU6mGDKdN5
# Hashtags Used:[]
#
# Tweet 79:
# Username:Trading_Sunset
# Description:Independent research, analysis, and commentary on the US equity/capital markets.
# Location:London, UK
# Following Count:5
# Follower Count:14576
# Total Tweets:83083
# Retweet Count:0
# Tweet Text:Tesla $TSLA is currently -8.6% at $985.00. Momentum due to turn negative in May. https://t.co/0foThDiOgU
# Hashtags Used:[]
#
# Tweet 80:
# Username:ShelleyMcCrory1
# Description:Former Corporate Media Exec Chillin' in the Midst of a Massive Political and Global Realignment.
#
# Live and Let Live, Can’t Lose.
# Location:California New Mexico
# Following Count:442
# Follower Count:1699
# Total Tweets:21401
# Retweet Count:9
# Tweet Text:I’ll say it again. It’s very strange that @elonmusk is lying in such a blatant and easily disprovable manner.
#
# Yeah the dude always lies. But this feels almost like he’s in a rush to rewrite history before “something” happens and he loses control of the narrative
#
# $tsla https://t.co/cDxvc7VGD2
# Hashtags Used:[]
#
# Tweet 81:
# Username:Tommy2thePoint
# Description:dude/guy; VAMO.
# Location:Oklahoma City, OK
# Following Count:4251
# Follower Count:1402
# Total Tweets:144711
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 82:
# Username:ayorandy_
# Description:Minimalism | Forward… 🚀📈
# Location:Maryland, USA
# Following Count:1638
# Follower Count:2119
# Total Tweets:72042
# Retweet Count:5
# Tweet Text:Typically when companies have poison pills the way around it is to make an offer they can’t refuse.  That’s one that’s high enough the majority would tender their shares. #twitter #tesla $twtr $tsla
# Hashtags Used:[]
#
# Tweet 83:
# Username:Hinge_t
# Description:
# Location:
# Following Count:1294
# Follower Count:204
# Total Tweets:11384
# Retweet Count:10
# Tweet Text:@BradMunchen @NHTSAgov @NTSB @HimoraSlimane Tesla Recalls Model X Over Front Side Airbags That Don't Inflate
#
# The recall affects model years 2021 and 2022 and encompasses a little over 7,000 vehicles.
#
# $TSLA $TSLAQ
#
# https://t.co/LU6mGDKdN5
# Hashtags Used:[]
#
# Tweet 84:
# Username:Zandriel6
# Description:old time gamer
# Location:
# Following Count:263
# Follower Count:167
# Total Tweets:14174
# Retweet Count:110
# Tweet Text:Musk Math:  Why Elon’s highest and final bid for $twtr is likely to be $69 per share, offered on 4/20. $tsla https://t.co/52scExBll3
# Hashtags Used:[]
#
# Tweet 85:
# Username:mjk631
# Description:
# Location:
# Following Count:541
# Follower Count:56
# Total Tweets:960
# Retweet Count:32
# Tweet Text:Different investment types have different goals
#
# You can have a MIXED plan as well and be VERY successful
#
# Dividends
# $KO
# $MO
# $HD
# $V
# $SBUX
#
# Blue Chip
# $AAPL
# #MSFT
# $GOOGL
# $AMZN
#
# Growth
# $TSLA
# $NVDA
# $CRWD
# $SQ
# $SHOP
#
# REITs
# $O
# $STOR
# $PSA
# $STAG
#
# Which is your GO TO type? https://t.co/u3BBdzltPe
# Hashtags Used:[]
#
# Tweet 86:
# Username:Zandriel6
# Description:old time gamer
# Location:
# Following Count:263
# Follower Count:167
# Total Tweets:14174
# Retweet Count:58
# Tweet Text:So Ark's base case for $TSLA is $22k/shr in 2030.
# Hashtags Used:[]
#
# Tweet 87:
# Username:MrYorroInvests
# Description:2022 I’m landing on the Moon 🚀🌕 #DayTrader #Investor #Options #SmallAccount - Not a Financial Advisor
# Location:
# Following Count:7
# Follower Count:30
# Total Tweets:208
# Retweet Count:0
# Tweet Text:$TWTR $TSLA $SPY
# Hashtags Used:[]
#
# Tweet 88:
# Username:WholeMarsBlog
# Description:part 24 hour EV news channel / part shitty stand up comedy routine
# Location:San Francisco, CA
# Following Count:13978
# Follower Count:59647
# Total Tweets:193513
# Retweet Count:5
# Tweet Text:Typically when companies have poison pills the way around it is to make an offer they can’t refuse.  That’s one that’s high enough the majority would tender their shares. #twitter #tesla $twtr $tsla
# Hashtags Used:[]
#
# Tweet 89:
# Username:contrarian8888
# Description:Former hedge fund manager of a multi billion dollar fund. Interested in commodities  & startups. Nothing should be construed as investment advice
# Location:New York, NY
# Following Count:735
# Follower Count:35957
# Total Tweets:10235
# Retweet Count:1
# Tweet Text:$TSLA Goodbye cool factor 😂
# Its like the time in high school when I finally got the cool designer jeans I wanted but the dorkiest kid in class got it one a week later.. I no longer felt cool wearing them🤣 https://t.co/ETv1el4Kxu
# Hashtags Used:[]
#
# Tweet 90:
# Username:PaperCutzEm
# Description:Minding my own black business
# Fear is for others
# #Bitcoin #Tesla #Arkinvest
# Location:Charleston
# Following Count:43
# Follower Count:129
# Total Tweets:420
# Retweet Count:58
# Tweet Text:So Ark's base case for $TSLA is $22k/shr in 2030.
# Hashtags Used:[]
#
# Tweet 91:
# Username:FryHangar
# Description:
# Location:
# Following Count:250
# Follower Count:101
# Total Tweets:2693
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 92:
# Username:Ray_Valencia_
# Description:Mr.President Bann #FSD⚰️FRAUD off the Roads & FakeAss Teflon into PRISON. Tesla is out of game because of the wrong faulty technology (No Lidar System) PERIOD!
# Location:Thank u Gary Gensler SEC💯0%👏
# Following Count:2
# Follower Count:0
# Total Tweets:276
# Retweet Count:9
# Tweet Text:I’ll say it again. It’s very strange that @elonmusk is lying in such a blatant and easily disprovable manner.
#
# Yeah the dude always lies. But this feels almost like he’s in a rush to rewrite history before “something” happens and he loses control of the narrative
#
# $tsla https://t.co/cDxvc7VGD2
# Hashtags Used:[]
#
# Tweet 93:
# Username:ohmahahm
# Description:테슬라 주주 커뮤니티 운영자
# (참여링크 : https://t.co/ssB7rGEvex)
# Location:Capitalism
# Following Count:3835
# Follower Count:17462
# Total Tweets:128891
# Retweet Count:41
# Tweet Text:For those who can’t get through Barron’s paywall.  $tsla $twtr https://t.co/VFQKaQaBzN
# Hashtags Used:[]
#
# Tweet 94:
# Username:TraderPBurns
# Description:Sharing Market commentary & Technical Analysis. Position Trader. Trend Follower. #Trading #Economics #Stocks #Forex. RT/Tweets = opinions not advice
# Location:Out of Nowhere
# Following Count:3940
# Follower Count:4326
# Total Tweets:131444
# Retweet Count:6
# Tweet Text:🚨Upcoming Earnings Report - Week of April 18th🚨
#
# $T $SNAP $TSLA $PG $CMA $ASML $JNJ $BAC $SAP $VZ $PM $BX $AN $AAL $FCX $UAL $CSX $ANTM $ABT $IBM $TRV $LMT $BK $HCA $NEM $CLF $ALV $KMB $SLB $AXP $MMC $QQQ $SPY
#
# ⬇️FREE 2 Weeks of Benzinga Pro⬇️
# https://t.co/CUiaiByn2z https://t.co/q7wQipmhq2
# Hashtags Used:[]
#
# Tweet 95:
# Username:JustStocksToday
# Description:Just stocks. That’s it. In fact my name is “Just Stocks”.
# Location:
# Following Count:1218
# Follower Count:464
# Total Tweets:56700
# Retweet Count:2
# Tweet Text:Musk Go-Private Tweet Ruled False by Judge, Tesla Investors Say $TSLA
#
# @elonmusk
# https://t.co/1UTFkcah7S
# Hashtags Used:[]
#
# Tweet 96:
# Username:kirillklip
# Description:Kirill Klip, MBA. Executive Chairman of #TNRGold. My blog “Private Diary: Chronicles of #Energy #rEVolution” NO investment advice. Links are NOT endorsed. #Gold
# Location:Planet #Earth, mostly.
# Following Count:7507
# Follower Count:7872
# Total Tweets:470802
# Retweet Count:2
# Tweet Text:TNR Gold Says Elon Musk Is Catalyst For Partial Ganfeng's Mariana Lithium Royalty Sale https://t.co/VgJHLZn4BP
#
# $TRRXF #TNRGold🔋 $TNR.v #Royalties⚡️ #MarianaLithium #Ganfeng #Lithium $GNENF $TSLA $LIT $BATT #EVs #Tesla #rEVolution $F $GM $ALB $SQM $LTHM $GDX $GDXJ https://t.co/8IchiWx94K
# Hashtags Used:[]
#
# Tweet 97:
# Username:VickiBryanBondA
# Description:Founder & CEO, Bond Angle, LLC 25 yrs high yield investment mgmt & research. Ok if Smart $ doesn't agree. We'll see. https://t.co/BM3lNAW70j
# Location:USA
# Following Count:2807
# Follower Count:3878
# Total Tweets:7777
# Retweet Count:10
# Tweet Text:@BradMunchen @NHTSAgov @NTSB @HimoraSlimane Tesla Recalls Model X Over Front Side Airbags That Don't Inflate
#
# The recall affects model years 2021 and 2022 and encompasses a little over 7,000 vehicles.
#
# $TSLA $TSLAQ
#
# https://t.co/LU6mGDKdN5
# Hashtags Used:[]
#
# Tweet 98:
# Username:VickiBryanBondA
# Description:Founder & CEO, Bond Angle, LLC 25 yrs high yield investment mgmt & research. Ok if Smart $ doesn't agree. We'll see. https://t.co/BM3lNAW70j
# Location:USA
# Following Count:2807
# Follower Count:3878
# Total Tweets:7777
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
#
# Tweet 99:
# Username:kenr0966
# Description:
# Location:41.136801,-73.986265
# Following Count:4594
# Follower Count:2134
# Total Tweets:141134
# Retweet Count:29
# Tweet Text:GOOD LORD...Earnings Season upon us
#
# This week notables: $NFLX $TSLA
# Following week: $MSFT $GOOG $AMZN $AAPL $TWTR $FB OH MY. PLACE YOUR BETS. https://t.co/inKwmbCLps
# Hashtags Used:[]
#
# Tweet 100:
# Username:hrafnkat
# Description:''Gathering flowers and carrying fire''  Heathen, nerd, news junkie, Ehlers-Danlos, TCK, bibliomane.  Perpetually 🤨
# Also @hrafnkatknits.  🚫 LISTS!
# Location:Pacific Northwest, US
# Following Count:13641
# Follower Count:12713
# Total Tweets:54181
# Retweet Count:103
# Tweet Text:Between April 1 and April 5, Elon Musk lost an important motion in federal court—in secret. As you can see, Document 387 is missing from the docket. As of today, we know it's a court order from Judge Chen that was lodged under seal. $TSLA https://t.co/MyBxnrpNl8
# Hashtags Used:[]
# Current directory = /Users/ravibyakod/WORK/Python/mec-mini-projects/mec-3.4.1-api-mini-project
